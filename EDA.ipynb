# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_gdp = pd.read_csv("gdp_pcap.csv")
df_co2 = pd.read_csv("co2_pcap_cons.csv")

# Drop the country abbreviation column
df_gdp = df_gdp.drop(columns=df_gdp.columns[0])
df_co2 = df_co2.drop(columns=df_co2.columns[0])

# Set country names as index
df_gdp = df_gdp.set_index(df_gdp.columns[0])
df_co2 = df_co2.set_index(df_co2.columns[0])

df_gdp.head()
# Out:
#                    1800        1801        1802        1803        1804  \
# name
# Afghanistan   560.88817   560.88817   560.88817   560.88817   560.88817
# Angola        435.23259   436.64111   438.75389   440.86667   442.27519
# Albania       547.53369   549.10393   550.67868   552.25795   553.84175
# Andorra      1598.53128  1601.20217  1603.87307  1607.87941  1610.55031
# UAE          1332.77712  1336.78346  1342.12526  1347.46705  1352.80884
#
#                    1805        1806        1807        1808        1809  ...  \
# name                                                                     ...
# Afghanistan   560.88817   560.88817   560.88817   560.88817   560.88817  ...
# Angola        444.38797   446.50074   448.61352   450.72630   452.13482  ...
# Albania       555.43009   557.02298   558.62044   560.22248   561.82912  ...
# Andorra      1613.22120  1615.89210  1618.56300  1622.56934  1625.24023  ...
# UAE          1356.81518  1362.15698  1367.49877  1372.84056  1378.18235  ...
#
#                     2091         2092         2093         2094         2095  \
# name
# Afghanistan   9397.79550   9628.20479   9864.18612  10105.83025  10353.22669
# Angola       30471.68022  30991.50308  31513.98698  32038.95027  32566.20896
# Albania      57444.50359  57884.32605  58319.28840  58749.34444  59174.45223
# Andorra      82535.68235  82627.86812  82718.08635  82806.37556  82892.77367
# UAE          81900.09821  81885.61721  81871.47395  81857.66048  81844.16902
#
#                     2096         2097         2098         2099         2100
# name
# Afghanistan  10606.46351  10865.62717  11130.80231  11402.07162  11679.51560
# Angola       33095.57701  33626.86659  34159.88835  34694.45172  35230.36514
# Albania      59594.57402  60009.67615  60419.72899  60824.70684  61224.58783
# Andorra      82977.31800  83060.04528  83140.99165  83220.19266  83297.68327
# UAE          81830.99199  81818.12198  81805.55176  81793.27428  81781.28265
#
# [5 rows x 301 columns]

# %%
print(df_gdp.index.difference(df_co2.index))
print(df_co2.index.difference(df_gdp.index))
# Out:
# Index(['Monaco', 'San Marino'], dtype='object', name='name')
# Index(['Liechtenstein'], dtype='object', name='name')

# %%
common = df_gdp.index.intersection(df_co2.index)

df_gdp = df_gdp.loc[common]
df_co2 = df_co2.loc[common]

print(df_gdp.index.difference(df_co2.index))
print(df_co2.index.difference(df_gdp.index))
# Out:
# Index([], dtype='object', name='name')
# Index([], dtype='object', name='name')

# %%
common_years = df_gdp.columns.intersection(df_co2.columns)

df_gdp = df_gdp[common_years]
df_co2 = df_co2[common_years]

df_gdp.columns.equals(df_co2.columns)

common_years = common_years.astype(int)

# %%
def plot_country(country):
    plt.figure(figsize=(7,5))

    scatter = plt.scatter(df_gdp.loc[country], df_co2.loc[country], s=30, c = common_years)
    
    plt.xlabel("GDP per Capita (constant international $ (2021))", fontsize=12)
    plt.ylabel("CO₂ Emissions per Capita (tonnes per capita)", fontsize=12)
    plt.title(f"{country}: CO2 vs GDP per capita", fontsize=14)
    
    plt.colorbar(scatter, label="Year")
    plt.grid(alpha=0.3)
    plt.tight_layout()
    plt.show()

plot_country("USA")

# %%
ß
